# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I chose the "Refresh / Content Opportunity Scoring" lane because it focuses on helping content and SEO teams decide which pages should be reviewed first for actions such as refreshing, expanding , protecting and monitoring.
# This is practical machine learning problem that supports real buisness decisions by prioritizing limited resources.
# I selected this lane because it builds on the starter notebooks and provides a clear path for developing a ranking model throughout the internship.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which pages should be reviewed first for content refresh?

# Who acts on it? The SEO or content team.

# Action: Review the highest-ranked pages and decide whether to refresh or improve them.

# Cost of a wrong call: Time may be wasted on the wrong pages while important pages are missed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/saadwasay210/saad-flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of pages: 30000
# Average CTR: 0.511
# Average impressions (90d): 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This project identifies observed patterns in search and content data to support decision-making. The recommendations are intended to help prioritize which pages should be reviewed first.

# This project does not prove that refreshing a page will improve rankings or traffic, and it does not predict Google's algorithm. Any recommendations should be reviewed by a human before actions are taken.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
