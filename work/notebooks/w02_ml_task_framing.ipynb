# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Lane: Refresh / Content Opportunity Scoring

# ML Task Type: Scoring (Ranking)

# The goal is to rank webpages according to how urgently they should be refreshed.
# Instead of simply classifying pages as "refresh" or "don't refresh," the model assigns each page a priority score so content teams can decide which pages should be updated first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# The target is a content opportunity score that estimates how strongly a page should be considered for a content refresh.

# Since the starter dataset does not contain a direct "needs refresh" label, the target will be created using observed search performance signals such as impressions, average position, CTR, content age, and trend direction.
#This serves as a proxy rather than a true labeled outcome.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# The main success metric is Precision@K because the goal is to rank the highest-priority pages first.
# A higher Precision@K means more of the recommended pages are truly good candidates for content refresh.

# This metric matches the ranking objective demonstrated in the starter notebooks.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/saadwasay210/saad-flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

lane_df = df[
    [
        "impressions_90d",
        "ctr",
        "avg_position",
        "content_age_days",
        "trend_direction"
    ]
]

lane_df.head()
# Out:
#    impressions_90d   ctr  avg_position  content_age_days trend_direction
# 0             3803  0.76          10.6               187            down
# 1            15320  0.05          20.3               445            down
# 2            12581  0.09          36.5               141            down
# 3            11751  0.49           6.2               463          stable
# 4            19140  0.13          44.0               263            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# A simple rule such as "refresh every page older than one year" or "refresh pages with low CTR" ignores the relationship between multiple search signals.

# Machine learning can analyze several features together, identify complex patterns, and rank pages according to their overall refresh priority.
#This provides better decision support than relying on one or two fixed rules.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
